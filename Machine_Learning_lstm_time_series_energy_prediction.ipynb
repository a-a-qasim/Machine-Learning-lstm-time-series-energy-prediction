# %% [markdown]
# # Data

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importing Data
URL = 'https://raw.githubusercontent.com/a-a-qasim/Machine-Learning-lstm-time-series-energy-prediction/refs/heads/master/events.csv'
df = pd.read_csv(URL)

# %% [markdown]
# ## Data Exploration

# %%
print("Return first 5 rows.","\n")
df.head()
# Out:
# Return first 5 rows.
#         Start time UTC         End time UTC Start time UTC+03:00  \
# 0  2015-12-31 21:00:00  2015-12-31 22:00:00  2016-01-01 00:00:00
# 1  2015-12-31 22:00:00  2015-12-31 23:00:00  2016-01-01 01:00:00
# 2  2015-12-31 23:00:00  2016-01-01 00:00:00  2016-01-01 02:00:00
# 3  2016-01-01 00:00:00  2016-01-01 01:00:00  2016-01-01 03:00:00
# 4  2016-01-01 01:00:00  2016-01-01 02:00:00  2016-01-01 04:00:00
#
#     End time UTC+03:00  Electricity consumption in Finland
# 0  2016-01-01 01:00:00                             10800.0
# 1  2016-01-01 02:00:00                             10431.0
# 2  2016-01-01 03:00:00                             10005.0
# 3  2016-01-01 04:00:00                              9722.0
# 4  2016-01-01 05:00:00                              9599.0

# %%
print("Return last 5 rows.","\n")
df.tail()
# Out:
# Return last 5 rows.
#             Start time UTC         End time UTC Start time UTC+03:00  \
# 52961  2021-12-31 16:00:00  2021-12-31 17:00:00  2021-12-31 19:00:00
# 52962  2021-12-31 17:00:00  2021-12-31 18:00:00  2021-12-31 20:00:00
# 52963  2021-12-31 18:00:00  2021-12-31 19:00:00  2021-12-31 21:00:00
# 52964  2021-12-31 19:00:00  2021-12-31 20:00:00  2021-12-31 22:00:00
# 52965  2021-12-31 20:00:00  2021-12-31 21:00:00  2021-12-31 23:00:00
#
#         End time UTC+03:00  Electricity consumption in Finland
# 52961  2021-12-31 20:00:00                             11447.0
# 52962  2021-12-31 21:00:00                             11237.0
# 52963  2021-12-31 22:00:00                             10914.0
# 52964  2021-12-31 23:00:00                             10599.0
# 52965  2022-01-01 00:00:00                             10812.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52966 entries, 0 to 52965
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Start time UTC                      52966 non-null  object
#  1   End time UTC                        52966 non-null  object
#  2   Start time UTC+03:00                52966 non-null  object
#  3   End time UTC+03:00                  52966 non-null  object
#  4   Electricity consumption in Finland  52966 non-null  float64
# dtypes: float64(1), object(4)
# memory usage: 2.0+ MB

# %%
#print("Descriptive statistics include those that summarize the central tendency, dispersion and shape of a dataset’s distribution, excluding NaN values.", "\n")
print(df.describe(), "\n")
# Out:
#        Electricity consumption in Finland
# count                        52966.000000
# mean                          9488.750519
# std                           1576.241673
# min                           5341.000000
# 25%                           8322.000000
# 50%                           9277.000000
# 75%                          10602.000000
# max                          15105.000000

# %% [markdown]
# ## Feature Extraction

# %%
cols_to_del = ["Start time UTC", "End time UTC", "Start time UTC+03:00"]
df.drop(columns=cols_to_del, inplace=True, errors='ignore')

df.rename(columns={"End time UTC+03:00":"DateTime","Electricity consumption in Finland":"Consumption"},inplace=True)
print(df.head(5))
# Out:
#               DateTime  Consumption
# 0  2016-01-01 01:00:00      10800.0
# 1  2016-01-01 02:00:00      10431.0
# 2  2016-01-01 03:00:00      10005.0
# 3  2016-01-01 04:00:00       9722.0
# 4  2016-01-01 05:00:00       9599.0

# %% [markdown]
# since we are dealing with time series data we should edite the index from 1 2 3 ... --> DateTime format.

# %%
# Convert to datetime once.
df['DateTime'] = pd.to_datetime(df['DateTime'])
dataset = df.copy() 

# Extract features (optimized).
dataset["Month"] = dataset["DateTime"].dt.month
dataset["Year"] = dataset["DateTime"].dt.year
dataset["Date"] = dataset["DateTime"].dt.date
dataset["Time"] = dataset["DateTime"].dt.time
dataset["Day"] = dataset["DateTime"].dt.day_name()

#  Fixed: Use of isocalendar to prevent the FutureWarning
dataset["Week"] = dataset["DateTime"].dt.isocalendar().week

# Set the DateTime as the index 
dataset.set_index("DateTime", inplace=True)
dataset.index = pd.to_datetime(dataset.index)

# %%
dataset.head()
# Out:
#                      Consumption  Month  Year        Date      Time     Day  \
# DateTime
# 2016-01-01 01:00:00      10800.0      1  2016  2016-01-01  01:00:00  Friday
# 2016-01-01 02:00:00      10431.0      1  2016  2016-01-01  02:00:00  Friday
# 2016-01-01 03:00:00      10005.0      1  2016  2016-01-01  03:00:00  Friday
# 2016-01-01 04:00:00       9722.0      1  2016  2016-01-01  04:00:00  Friday
# 2016-01-01 05:00:00       9599.0      1  2016  2016-01-01  05:00:00  Friday
#
#                      Week
# DateTime
# 2016-01-01 01:00:00    53
# 2016-01-01 02:00:00    53
# 2016-01-01 03:00:00    53
# 2016-01-01 04:00:00    53
# 2016-01-01 05:00:00    53

# %%
print(f"Dataset spans from {dataset.index.min()} to {dataset.index.max()}")
print(f"Total Number of Years: {dataset.Year.nunique()}")
print(dataset.Year.unique())
# Out:
# Dataset spans from 2016-01-01 01:00:00 to 2022-01-01 00:00:00
# Total Number of Years: 7
# [2016 2017 2018 2019 2020 2021 2022]

# %%
# By assuming week starts on Mondey and ends on Sunday.
# The closest start would be on Monday 4-1-2016 
# The closest end would be on sunday 26-12-2021
# So we should omit first 71 rows and last 121 rows.
dataset = dataset[71:-121]
dataset.tail()
# Out:
#                      Consumption  Month  Year        Date      Time     Day  \
# DateTime
# 2021-12-26 19:00:00      12550.0     12  2021  2021-12-26  19:00:00  Sunday
# 2021-12-26 20:00:00      12622.0     12  2021  2021-12-26  20:00:00  Sunday
# 2021-12-26 21:00:00      12574.0     12  2021  2021-12-26  21:00:00  Sunday
# 2021-12-26 22:00:00      12384.0     12  2021  2021-12-26  22:00:00  Sunday
# 2021-12-26 23:00:00      12044.0     12  2021  2021-12-26  23:00:00  Sunday
#
#                      Week
# DateTime
# 2021-12-26 19:00:00    51
# 2021-12-26 20:00:00    51
# 2021-12-26 21:00:00    51
# 2021-12-26 22:00:00    51
# 2021-12-26 23:00:00    51

# %% [markdown]
# ## Data Visualizations

# %%
from matplotlib import style
# Modern Seaborn approach (No method change)
plt.figure(figsize=(20, 10))
style.use("ggplot")

sns.lineplot(x="Year", y="Consumption", data=dataset, color="blue", label='Avg Consumption')

plt.title("Electricity Consumption in Finland 2016-2021")
plt.xlabel("Year")
plt.ylabel("Energy in MW")
plt.xticks(rotation=90) # Simpler way to rotate ticks
plt.grid(True)
plt.legend() # Now has a label to show
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.plot(dataset["Consumption"], color="royalblue")

# %%
# Energy Consumption Each Year
from matplotlib import style

fig = plt.figure(figsize = (30,30))

ax1 = fig.add_subplot(611)
ax2 = fig.add_subplot(612)
ax3 = fig.add_subplot(613)
ax4 = fig.add_subplot(614)
ax5 = fig.add_subplot(615)
ax6 = fig.add_subplot(616)

style.use("ggplot")

y_2016 = dataset.loc["2016"]["Consumption"].to_list()
x_2016 = dataset.loc["2016"]["Date"].to_list()
ax1.plot(x_2016, y_2016, label="Consumption", color= "blue", linewidth= 1.7)

y_2017 = dataset.loc["2017"]["Consumption"].to_list()
x_2017 = dataset.loc["2017"]["Date"].to_list()
ax2.plot(x_2017, y_2017, label="Consumption", color= "blue", linewidth= 1.7)

y_2018 = dataset.loc["2018"]["Consumption"].to_list()
x_2018 = dataset.loc["2018"]["Date"].to_list()
ax3.plot(x_2018, y_2018, label="Consumption", color= "blue", linewidth= 1.7)

y_2019 = dataset.loc["2019"]["Consumption"].to_list()
x_2019 = dataset.loc["2019"]["Date"].to_list()
ax4.plot(x_2019, y_2019, label="Consumption", color= "blue", linewidth= 1.7)

y_2020 = dataset.loc["2020"]["Consumption"].to_list()
x_2020 = dataset.loc["2020"]["Date"].to_list()
ax5.plot(x_2020, y_2020, label="Consumption", color= "blue", linewidth= 1.7)

y_2021 = dataset.loc["2021"]["Consumption"].to_list()
x_2021 = dataset.loc["2021"]["Date"].to_list()
ax6.plot(x_2021, y_2021, label="Consumption", color= "blue", linewidth= 1.7)

plt.rcParams["figure.figsize"] = (30, 15)
plt.subplots_adjust(left=0.1, bottom=0.1, right=0.9, top=2.5, wspace=0.4, hspace=0.4)
plt.title("Energy Consumption")
plt.xlabel("Date")
plt.ylabel("Energy in MW")
plt.grid(True, alpha=1)
plt.legend()

# %%
# Updated modern version of the distribution plot
plt.figure(figsize=(15, 10))

# histplot replaces distplot
sns.histplot(dataset["Consumption"], kde=True, stat="density", color="coral") 

plt.title("Energy Distribution")
plt.xlabel("Consumption (MW)")
plt.ylabel("Density")
plt.show()

# %%
plt.figure(figsize=(15, 10))

# Fixed: Using the correct dataframe 'dataset'
sns.boxplot(x="Month", y="Consumption", data=dataset, hue="Month", palette="husl", legend=False)

plt.title("Energy Consumption VS Month (Seasonal Trends)")
plt.xlabel("Month")
plt.ylabel("Consumption (MW)")
plt.grid(True, alpha=0.3)

plt.show()

# %%
# Create a copy for specific hourly analysis
dataset1 = dataset.copy()

plt.figure(figsize=(15, 10))

#  ensure we are using 'dataset1.index.hour' for the x-axis.
sns.boxplot(x=dataset1.index.hour, y=dataset1.Consumption, hue=dataset1.index.hour, palette="husl", legend=False)

plt.title("Energy Consumption VS Hour (Daily Cycle)")
plt.xlabel("Hour of the Day")
plt.ylabel("Consumption (MW)")
plt.grid(True, alpha=0.3)

plt.show()

# %%
plt.figure(figsize=(15, 10))

sns.boxplot(x=dataset1.index.year, y=dataset1.Consumption, hue=dataset1.index.year, palette="husl", legend=False)

plt.title("Energy Consumption VS Year (Annual Comparison)")
plt.xlabel("Year")
plt.ylabel("Consumption (MW)")
plt.grid(True, alpha=0.3)
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# # LSTM Model

# %% [markdown]
# ## Train, Validation and Test Dataset

# %%
# Downsampling involves decreasing the time-frequency of the data
# Downsapling the time-frequency from hours to days 
newDataSet = dataset.resample("D").mean(numeric_only=True)

# %%
# We have 2193 row
# 2193 - 3 - 6 = 2184 row after omit first two rows and last six ones.  
# 2184 / 7 = 312 week  
# 312 * 80 %  250 week for train (1750 day)  
# 312 - 250 = 62 week for test (434 day)
print("Old Dataset: ", dataset.shape)
print("New Dataset: ", newDataSet.shape)
# Out:
# Old Dataset:  (52774, 7)
# New Dataset:  (2184, 4)

# %%
# Saving data in CSV new file
newDataSet.to_csv("newDataSet.csv")
# from google.colab import files
# files.download("newDataSet.csv")

# %%
newDataSet.head()
# Out:
#              Consumption  Month    Year  Week
# DateTime
# 2016-01-04  12300.625000    1.0  2016.0   1.0
# 2016-01-05  12945.375000    1.0  2016.0   1.0
# 2016-01-06  13192.750000    1.0  2016.0   1.0
# 2016-01-07  14243.541667    1.0  2016.0   1.0
# 2016-01-08  14121.666667    1.0  2016.0   1.0

# %%
y = newDataSet["Consumption"]
print(y.iloc[0])
y.shape
# Out:
# 12300.625
# (2184,)

# %%
# Normalize data before model fitting
# it will boost the performance( in neural networks) + transform
from sklearn.preprocessing import MinMaxScaler
# scale of the output and input inthe range 0-1 to match the scale of the layer of LSTM
scaler = MinMaxScaler(feature_range = (0,1)) 
# reshape: convert the univariate 1D array into 2D
y = scaler.fit_transform(np.array(y).reshape(-1,1))
print("Normalizing data before model fitting")
print(y[:10])
# Out:
# Normalizing data before model fitting
# [[0.75916744]
#  [0.83908687]
#  [0.86975003]
#  [1.        ]
#  [0.98489309]
#  [0.82500258]
#  [0.78623593]
#  [0.83189672]
#  [0.80348621]
#  [0.8313604 ]]

# %%
training_size = int(len(y)*0.80)
test_size = len(y)- training_size
val_size = int(training_size*0.20)
train_data , test_data , val_data = y[0:training_size-val_size,:] , y[training_size:len(y),:1], y[len(y)-test_size-val_size:len(y)-test_size,:1]

# %%
# building input variable
def create_dataset(dataset, time_step = 1):
  dataX, dataY = [] , []
  for i in range(len(dataset)-time_step-1):
    a = dataset[i:(i+time_step),0]
    dataX.append(a)
    dataY.append(dataset[i + time_step,0])
  return np.array(dataX), np.array(dataY)

# %%
time_step = 100 
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)
X_val, yval = create_dataset(val_data, time_step)

# %%
# reshape train and input-output pairs
X_train = X_train.reshape(X_train.shape[0],X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1],1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1],1)

print("X_train shape: ", X_train.shape)
print("X_test shape: ",X_test.shape)
print("X_val shape: ",X_val.shape)
# Out:
# X_train shape:  (1297, 100, 1)
# X_test shape:  (336, 100, 1)
# X_val shape:  (248, 100, 1)

# %% [markdown]
# ## Model Structure

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

model = Sequential()

# Adding the first LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True, input_shape = (time_step, 1)))
model.add(Dropout(0.2))

# Adding a second LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
# model.add(Dropout(0.2))

# # Adding a third LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
# model.add(Dropout(0.2))

# Adding a fourth LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50))
# model.add(Dropout(0.2))

# Adding the output layer
model.add(Dense(units = 1))

# Compiling the RNN
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  dropout (Dropout)           (None, 100, 50)           0
#
#  lstm_1 (LSTM)               (None, 100, 50)           20200
#
#  lstm_2 (LSTM)               (None, 100, 50)           20200
#
#  lstm_3 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 71051 (277.54 KB)
# Trainable params: 71051 (277.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Model Training

# %%
history = model.fit(X_train, y_train, validation_data = (X_val,yval), verbose = 1,epochs = 60 ,batch_size = 20)
# Out:
# Epoch 1/60
# 65/65 [==============================] - 22s 194ms/step - loss: 0.0177 - val_loss: 0.0051
# Epoch 2/60
# 65/65 [==============================] - 11s 177ms/step - loss: 0.0071 - val_loss: 0.0042
# Epoch 3/60
# 65/65 [==============================] - 12s 190ms/step - loss: 0.0074 - val_loss: 0.0050
# Epoch 4/60
# 65/65 [==============================] - 11s 168ms/step - loss: 0.0066 - val_loss: 0.0044
# Epoch 5/60
# 65/65 [==============================] - 12s 177ms/step - loss: 0.0060 - val_loss: 0.0039
# Epoch 6/60
# 65/65 [==============================] - 11s 168ms/step - loss: 0.0062 - val_loss: 0.0037
# Epoch 7/60
# 65/65 [==============================] - 13s 193ms/step - loss: 0.0054 - val_loss: 0.0036
# Epoch 8/60
# 65/65 [==============================] - 13s 199ms/step - loss: 0.0056 - val_loss: 0.0035
# Epoch 9/60
# 65/65 [==============================] - 11s 169ms/step - loss: 0.0056 - val_loss: 0.0041
# Epoch 10/60
# 65/65 [==============================] - 13s 204ms/step - loss: 0.0049 - val_loss: 0.0034
# Epoch 11/60
# 65/65 [==============================] - 14s 216ms/step - loss: 0.0050 - val_loss: 0.0036
# Epoch 12/60
# 65/65 [==============================] - 12s 180ms/step - loss: 0.0052 - val_loss: 0.0037
# Epoch 13/60
# 65/65 [==============================] - 12s 182ms/step - loss: 0.0046 - val_loss: 0.0033
# Epoch 14/60
# 65/65 [==============================] - 12s 189ms/step - loss: 0.0048 - val_loss: 0.0035
# Epoch 15/60
# 65/65 [==============================] - 14s 214ms/step - loss: 0.0046 - val_loss: 0.0034
# Epoch 16/60
# 65/65 [==============================] - 11s 172ms/step - loss: 0.0047 - val_loss: 0.0034
# Epoch 17/60
# 65/65 [==============================] - 11s 171ms/step - loss: 0.0044 - val_loss: 0.0036
# Epoch 18/60
# 65/65 [==============================] - 14s 208ms/step - loss: 0.0047 - val_loss: 0.0033
# Epoch 19/60
# 65/65 [==============================] - 11s 175ms/step - loss: 0.0053 - val_loss: 0.0034
# Epoch 20/60
# 65/65 [==============================] - 14s 213ms/step - loss: 0.0045 - val_loss: 0.0034
# Epoch 21/60
# 65/65 [==============================] - 12s 186ms/step - loss: 0.0046 - val_loss: 0.0034
# Epoch 22/60
# 65/65 [==============================] - 11s 164ms/step - loss: 0.0047 - val_loss: 0.0041
# Epoch 23/60
# 65/65 [==============================] - 13s 201ms/step - loss: 0.0043 - val_loss: 0.0032
# Epoch 24/60
# 65/65 [==============================] - 13s 195ms/step - loss: 0.0042 - val_loss: 0.0033
# Epoch 25/60
# 65/65 [==============================] - 14s 214ms/step - loss: 0.0040 - val_loss: 0.0029
# Epoch 32/60
# 65/65 [==============================] - 14s 214ms/step - loss: 0.0041 - val_loss: 0.0031
# Epoch 33/60
# 65/65 [==============================] - 13s 190ms/step - loss: 0.0038 - val_loss: 0.0028
# Epoch 34/60
# 65/65 [==============================] - 11s 169ms/step - loss: 0.0037 - val_loss: 0.0030
# Epoch 35/60
# 65/65 [==============================] - 11s 175ms/step - loss: 0.0037 - val_loss: 0.0029
# Epoch 36/60
# 65/65 [==============================] - 13s 193ms/step - loss: 0.0035 - val_loss: 0.0027
# Epoch 37/60
# 65/65 [==============================] - 13s 206ms/step - loss: 0.0037 - val_loss: 0.0027
# Epoch 38/60
# 65/65 [==============================] - 11s 171ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 39/60
# 65/65 [==============================] - 12s 182ms/step - loss: 0.0034 - val_loss: 0.0029
# Epoch 40/60
# 65/65 [==============================] - 12s 181ms/step - loss: 0.0035 - val_loss: 0.0030
# Epoch 41/60
# 65/65 [==============================] - 12s 192ms/step - loss: 0.0032 - val_loss: 0.0026
# Epoch 42/60
# 65/65 [==============================] - 14s 215ms/step - loss: 0.0033 - val_loss: 0.0024
# Epoch 43/60
# 65/65 [==============================] - 12s 183ms/step - loss: 0.0032 - val_loss: 0.0024
# Epoch 44/60
# 65/65 [==============================] - 13s 197ms/step - loss: 0.0034 - val_loss: 0.0030
# Epoch 45/60
# 65/65 [==============================] - 13s 196ms/step - loss: 0.0030 - val_loss: 0.0026
# Epoch 46/60
# 65/65 [==============================] - 13s 193ms/step - loss: 0.0030 - val_loss: 0.0024
# Epoch 47/60
# 65/65 [==============================] - 12s 186ms/step - loss: 0.0030 - val_loss: 0.0023
# Epoch 48/60
# 65/65 [==============================] - 13s 197ms/step - loss: 0.0029 - val_loss: 0.0027
# Epoch 49/60
# 65/65 [==============================] - 13s 208ms/step - loss: 0.0028 - val_loss: 0.0022
# Epoch 50/60
# 65/65 [==============================] - 13s 197ms/step - loss: 0.0029 - val_loss: 0.0021
# Epoch 51/60
# 65/65 [==============================] - 15s 228ms/step - loss: 0.0030 - val_loss: 0.0021
# Epoch 52/60
# 65/65 [==============================] - 13s 206ms/step - loss: 0.0028 - val_loss: 0.0021
# Epoch 53/60
# 65/65 [==============================] - 11s 170ms/step - loss: 0.0027 - val_loss: 0.0021
# Epoch 54/60
# 65/65 [==============================] - 13s 194ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 55/60
# 65/65 [==============================] - 13s 197ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 56/60
# 65/65 [==============================] - 15s 236ms/step - loss: 0.0026 - val_loss: 0.0019
# Epoch 57/60
# 65/65 [==============================] - 13s 206ms/step - loss: 0.0027 - val_loss: 0.0018
# Epoch 58/60
# 65/65 [==============================] - 12s 193ms/step - loss: 0.0026 - val_loss: 0.0018
# Epoch 59/60
# 65/65 [==============================] - 12s 184ms/step - loss: 0.0025 - val_loss: 0.0017
# Epoch 60/60
# 65/65 [==============================] - 11s 169ms/step - loss: 0.0025 - val_loss: 0.0018

# %%
# model_save_name = 'LSTM-Model2022.h5'
# path = F"/content/gdrive/My Drive/{model_save_name}" 
# torch.save(model, path)
# The modern and safest way to save your LSTM
model.save('Finland_Energy_Model.keras')

# %% [markdown]
# ## Model Evaluating

# %%
plt.figure(figsize=(10,10))
plt.plot(history.history['loss']) # tb
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.14.0'

# %%
### Lets Do the prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
val_predict=model.predict(X_val)
# Out:
# 41/41 [==============================] - 5s 49ms/step
# 11/11 [==============================] - 1s 91ms/step
# 8/8 [==============================] - 1s 65ms/step

# %%
##Transformback to original form
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)
val_predict=scaler.inverse_transform(val_predict)

# %%
# Transform the actual target values back to Megawatts
y_train_inv = scaler.inverse_transform(y_train.reshape(-1, 1))
y_test_inv = scaler.inverse_transform(ytest.reshape(-1, 1))

# Now calculate the real RMSE using the transformed 'y_train_inv'
import math
from sklearn.metrics import mean_squared_error
rmse_score = math.sqrt(mean_squared_error(y_train_inv, train_predict))

print(f"The actual error in Megawatts is: {rmse_score} MW")
# Out:
# The actual error in Megawatts is: 365.9164068086928 MW

# %%
print(train_predict.shape)
print(test_predict.shape)
print(val_predict.shape)
print(train_predict[0])
print(y_train.shape)
# Out:
# (1297, 1)
# (336, 1)
# (248, 1)
# [9366.949]
# (1297,)

# %% [markdown]
# # Conclusion

# %%
# Predicting consumption using training data
train_predictions = model.predict(X_train)
train_predictions =scaler.inverse_transform(train_predictions)

y_train = y_train.reshape(y_train.shape[0], 1)
actual = scaler.inverse_transform(y_train)
train_results = pd.DataFrame()

train_results["Train Predictions"] = train_predictions.tolist()
train_results["Actuals"] = actual.tolist()

train_results
# Out:
# 41/41 [==============================] - 5s 106ms/step
#       Train Predictions               Actuals
# 0       [9366.94921875]   [9406.708333333334]
# 1       [9444.89453125]   [9614.791666666666]
# 2       [9498.96484375]   [9894.708333333334]
# 3     [9712.9794921875]   [8933.708333333334]
# 4     [8891.6396484375]   [8557.208333333334]
# ...                 ...                   ...
# 1292   [9197.228515625]   [9259.666666666666]
# 1293  [9497.5830078125]             [10248.5]
# 1294  [10240.548828125]  [10360.333333333334]
# 1295  [10043.134765625]  [10489.833333333334]
# 1296     [10225.109375]             [10204.5]
#
# [1297 rows x 2 columns]

# %%
plt.figure(figsize=(20,10))

# Actual Consumption
ActualPlot = np.empty_like(y )
ActualPlot[:, :] = np.nan
ActualPlot[887:, :] = actual.tolist()
plt.plot(ActualPlot)

TrainPredictionsPlot = np.empty_like(y )
TrainPredictionsPlot[:, :] = np.nan
TrainPredictionsPlot[887:, :] = train_predictions.tolist()
plt.plot(TrainPredictionsPlot)

plt.legend(['actual','train_predictions'])
plt.xlabel('Time Steps')
plt.ylabel('Consumption MWh')
plt.show()

# %%
# Predicting consumption using validation data
val_predictions = model.predict(X_val)
val_predictions =scaler.inverse_transform(val_predictions)

yval = yval.reshape(yval.shape[0], 1)
actual_val = scaler.inverse_transform(yval)

val_results = pd.DataFrame()
val_results["Val Predictions"] = val_predictions.tolist()
val_results["Actuals_val"] = actual_val.tolist()

val_results
# Out:
# 8/8 [==============================] - 1s 113ms/step
#        Val Predictions           Actuals_val
# 0    [9440.4580078125]            [8931.875]
# 1    [9828.8779296875]   [9112.916666666666]
# 2     [9677.294921875]  [10019.416666666666]
# 3    [10082.611328125]           [10390.375]
# 4    [9992.6044921875]  [10802.916666666666]
# ..                 ...                   ...
# 243  [8418.8798828125]   [8020.541666666667]
# 244  [8132.0498046875]             [7921.75]
# 245     [8205.8671875]   [8705.041666666666]
# 246      [8698.984375]   [8824.708333333334]
# 247  [8713.0537109375]            [9062.375]
#
# [248 rows x 2 columns]

# %%
plt.figure(figsize=(20,10))

# Actual Consumption
ActualPlot = np.empty_like(y)
ActualPlot[:, :] = np.nan
ActualPlot[1936:, :] = actual_val.tolist()
plt.plot(ActualPlot)

# Validation Prediction
ValPredictionsPlot = np.empty_like(y)
ValPredictionsPlot[:, :] = np.nan
ValPredictionsPlot[1936:, :] = val_predictions.tolist()
plt.plot(ValPredictionsPlot)

plt.legend(['actual_val','Val_predictions'])
plt.xlabel('Time Steps')
plt.ylabel('Consumption MWh')
# Out:
# Text(0, 0.5, 'Consumption MWh')

# %%
# Predicting consumption using test data
test_predictions = model.predict(X_test)
test_predictions =scaler.inverse_transform(test_predictions)

ytest = ytest.reshape(ytest.shape[0], 1)
actual_test = scaler.inverse_transform(ytest)

test_results = pd.DataFrame()
test_results["test Predictions"] = test_predictions.tolist()
test_results["Actuals_test"] = actual_test.tolist()

test_results
# Out:
# 11/11 [==============================] - 1s 116ms/step
#        test Predictions          Actuals_test
# 0     [10562.541015625]  [10032.541666666666]
# 1      [10431.93359375]           [10732.125]
# 2    [11109.4677734375]  [10733.583333333334]
# 3    [10790.3974609375]           [10971.875]
# 4    [11122.5322265625]  [11227.791666666666]
# ..                  ...                   ...
# 331  [12651.4287109375]            [12540.25]
# 332   [12348.326171875]  [12635.958333333334]
# 333  [12693.1728515625]  [11684.333333333334]
# 334    [11317.68359375]  [11384.166666666666]
# 335  [12151.7041015625]           [11581.625]
#
# [336 rows x 2 columns]

# %%
plt.figure(figsize=(20,10))

# Actual Consumption
ActualPlot = np.empty_like(y)
ActualPlot[:, :] = np.nan
ActualPlot[1848:, :] = actual_test.tolist()
plt.plot(ActualPlot)

# Test Prediction
TestPredictionsPlot = np.empty_like(y)
TestPredictionsPlot[:, :] = np.nan
TestPredictionsPlot[1848:, :] = test_predictions.tolist()
plt.plot(TestPredictionsPlot)

plt.legend(['Actual_test','Test_predictions'])
plt.xlabel('Time Steps')
plt.ylabel('Consumption MWh')
# Out:
# Text(0, 0.5, 'Consumption MWh')

# %%
### Plotting 
# shift train predictions for plotting
look_back=100 #*****************************************>>>>>100
fig, ax = plt.subplots(figsize=(20,10))
trainPredictPlot = np.empty_like(y)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
# shift test predictions for plotting
testPredictPlot = np.empty_like(y)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(train_predict)+(look_back*2)+1+349:len(y)-1, :] = test_predict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(y))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.legend(['inverse_transform(y)','trainPredictPlot','testPredictPlot'])
plt.xlabel('Time Steps')
plt.ylabel('Consumption MWh')
plt.show()

# %% [markdown]
# # Future forecasting

# %%
print(len(test_data))
print(test_data[0])
print(len(train_data))
x_input=test_data[337:].reshape(1,-1)
print(x_input.shape)
# print(x_input[0])
temp_input=list(x_input)
temp_input=temp_input[0].tolist()
# print(temp_input)
# Out:
# 437
# [0.40285095]
# 1398
# (1, 100)

# %%
# demonstrate prediction for next 30 days
from numpy import array

lst_output=[]
n_steps=100
i=0
test = ""
while(i<30):
    
    if(len(temp_input)>100):
        test = "if"
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        test="else"
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        #print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        #print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1

    
print(test)
print(len(lst_output))
# Out:
# 1 day input [0.25709121 0.33563165 0.36255552 0.36498812 0.36948662 0.37489412
#  0.30034604 0.25916744 0.35327446 0.35606342 0.3529749  0.36009193
#  0.36937816 0.28358124 0.249561   0.32426919 0.3429811  0.33217643
#  0.32601487 0.34354922 0.27053507 0.25411631 0.33202665 0.36575767
#  0.38037909 0.41900114 0.40965809 0.36264332 0.34998967 0.43912819
#  0.48126743 0.46479186 0.40083153 0.44962814 0.44524842 0.45453466
#  0.45160624 0.42284888 0.4359467  0.44960748 0.42327755 0.3690941
#  0.3264797  0.41017457 0.42818407 0.44249561 0.41147609 0.44483008
#  0.39457184 0.43183555 0.53842578 0.59736597 0.49454602 0.47844231
#  0.49448921 0.47407293 0.45992666 0.57367524 0.49652928 0.4854922
#  0.46876872 0.51486933 0.46267431 0.46884619 0.620282   0.62459457
#  0.57526598 0.59118893 0.62118583 0.6655046  0.66726578 0.74881727
#  0.7883793  0.77671212 0.78571429 0.80647144 0.74484041 0.82660366
#  0.82588059 0.87828737 0.91723995 0.87967669 0.80140998 0.65632683
#  0.57681025 0.63147402 0.59401921 0.59759839 0.5892883  0.61484351
#  0.55500981 0.54768619 0.74439624 0.78886995 0.8007334  0.68277554
#  0.64556864 0.67004442 0.71099576 0.760831  ]
# 1 day output [[0.77257276]]
# 2 day input [0.33563165 0.36255552 0.36498812 0.36948662 0.37489412 0.30034604
#  0.25916744 0.35327446 0.35606342 0.3529749  0.36009193 0.36937816
#  0.28358124 0.249561   0.32426919 0.3429811  0.33217643 0.32601487
#  0.34354922 0.27053507 0.25411631 0.33202665 0.36575767 0.38037909
#  0.41900114 0.40965809 0.36264332 0.34998967 0.43912819 0.48126743
#  0.46479186 0.40083153 0.44962814 0.44524842 0.45453466 0.45160624
#  0.42284888 0.4359467  0.44960748 0.42327755 0.3690941  0.3264797
#  0.41017457 0.42818407 0.44249561 0.41147609 0.44483008 0.39457184
#  0.43183555 0.53842578 0.59736597 0.49454602 0.47844231 0.49448921
#  0.47407293 0.45992666 0.57367524 0.49652928 0.4854922  0.46876872
#  0.51486933 0.46267431 0.46884619 0.620282   0.62459457 0.57526598
#  0.59118893 0.62118583 0.6655046  0.66726578 0.74881727 0.7883793
#  0.77671212 0.78571429 0.80647144 0.74484041 0.82660366 0.82588059
#  0.87828737 0.91723995 0.87967669 0.80140998 0.65632683 0.57681025
#  0.63147402 0.59401921 0.59759839 0.5892883  0.61484351 0.55500981
#  0.54768619 0.74439624 0.78886995 0.8007334  0.68277554 0.64556864
#  0.67004442 0.71099576 0.760831   0.77257276]
# 2 day output [[0.76214993]]
# 3 day input [0.36255552 0.36498812 0.36948662 0.37489412 0.30034604 0.25916744
#  0.35327446 0.35606342 0.3529749  0.36009193 0.36937816 0.28358124
#  0.249561   0.32426919 0.3429811  0.33217643 0.32601487 0.34354922
#  0.27053507 0.25411631 0.33202665 0.36575767 0.38037909 0.41900114
#  0.40965809 0.36264332 0.34998967 0.43912819 0.48126743 0.46479186
#  0.40083153 0.44962814 0.44524842 0.45453466 0.45160624 0.42284888
#  0.4359467  0.44960748 0.42327755 0.3690941  0.3264797  0.41017
0.66726578 0.74881727 0.7883793  0.77671212 0.78571429
#  0.80647144 0.74484041 0.82660366 0.82588059 0.87828737 0.91723995
#  0.87967669 0.80140998 0.65632683 0.57681025 0.63147402 0.59401921
#  0.59759839 0.5892883  0.61484351 0.55500981 0.54768619 0.74439624
#  0.78886995 0.8007334  0.68277554 0.64556864 0.67004442 0.71099576
#  0.760831   0.77257276 0.76214993 0.75036108 0.74542379 0.75043738
#  0.76013505 0.76790291 0.77121902 0.77107424 0.76965278 0.76871032
#  0.76885867 0.769719   0.77057868 0.77094078 0.7707032  0.77003789
#  0.76916951 0.76823622 0.76726389 0.76620877 0.76501191 0.76365012
#  0.76214141 0.76051879 0.75881445 0.75705063]
# 28 day output [[0.7552385]]
# 29 day input [0.34998967 0.43912819 0.48126743 0.46479186 0.40083153 0.44962814
#  0.44524842 0.45453466 0.45160624 0.42284888 0.4359467  0.44960748
#  0.42327755 0.3690941  0.3264797  0.41017457 0.42818407 0.44249561
#  0.41147609 0.44483008 0.39457184 0.43183555 0.53842578 0.59736597
#  0.49454602 0.47844231 0.49448921 0.47407293 0.45992666 0.57367524
#  0.49652928 0.4854922  0.46876872 0.51486933 0.46267431 0.46884619
#  0.620282   0.62459457 0.57526598 0.59118893 0.62118583 0.6655046
#  0.66726578 0.74881727 0.7883793  0.77671212 0.78571429 0.80647144
#  0.74484041 0.82660366 0.82588059 0.87828737 0.91723995 0.87967669
#  0.80140998 0.65632683 0.57681025 0.63147402 0.59401921 0.59759839
#  0.5892883  0.61484351 0.55500981 0.54768619 0.74439624 0.78886995
#  0.8007334  0.68277554 0.64556864 0.67004442 0.71099576 0.760831
#  0.77257276 0.76214993 0.75036108 0.74542379 0.75043738 0.76013505
#  0.76790291 0.77121902 0.77107424 0.76965278 0.76871032 0.76885867
#  0.769719   0.77057868 0.77094078 0.7707032  0.77003789 0.76916951
#  0.76823622 0.76726389 0.76620877 0.76501191 0.76365012 0.76214141
#  0.76051879 0.75881445 0.75705063 0.75523847]
# 29 day output [[0.7533851]]
# if
# 30

# %%
print(len(y))
day_new=np.arange(1,101)
day_pred=np.arange(101, 131 )
plt.figure(figsize = (15,10))
plt.plot(day_new,scaler.inverse_transform(y[2084:]))
plt.plot(day_pred,scaler.inverse_transform(lst_output))
print(scaler.inverse_transform(lst_output))
# Out:
# 2184
# [[12314.04574643]
#  [12408.77237419]
#  [12324.68622694]
#  [12229.5797194 ]
#  [12189.74812309]
#  [12230.19522081]
#  [12308.43121956]
#  [12371.09839881]
#  [12397.85107116]
#  [12396.68306107]
#  [12385.21550054]
#  [12377.61213476]
#  [12378.80899648]
#  [12385.74973653]
#  [12392.68518711]
#  [12395.60641448]
#  [12393.68970464]
#  [12388.32234005]
#  [12381.31668384]
#  [12373.78737057]
#  [12365.9430937 ]
#  [12357.43090163]
#  [12347.77522335]
#  [12336.78900416]
#  [12324.6174639 ]
#  [12311.52699927]
#  [12297.77727495]
#  [12283.54765187]
#  [12268.92805095]
#  [12253.97617544]]

# %%
df3=y.tolist()
df3.extend(lst_output)
plt.figure(figsize=(15,10))
plt.plot(df3[2000:])
